# %%
import boto3
from botocore.exceptions import NoCredentialsError

# %%
local_path = "C:/Users/user/Documents/Archivo Ejemplo/Ejemplo Excel.xlsx"
bucket = "my-bucket"
s3_path = "Fuentes/Excel/Prueba Ruta/Excel en AWS.xlsx"

# %%
s3 = boto3.client('s3')
try:
    s3.upload_file(local_path, bucket, s3_path)
    print("Archivo subido exitosamente")
except FileNotFoundError:
    print("Archivo no encontrado")
except NoCredentialsError:
    print("Credenciales Erróneas")
# Out:
# Credenciales Erroneas

# %% [markdown]
# ## Archivo referenciado en local_path
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Listado de Bucket
# ![image.png](attachment:image.png)
# Para ver los Bucket o crear uno buscar el servicio S3 en AWS

# %% [markdown]
# ## Archivo destino
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Se debe tener configurada las conexiones en las variables de entorno
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Resultado de ejecución
# ![image.png](attachment:image.png)
